# %% [markdown]
# # Housing-in-Mexico
# Starter notebook for the Housing-in-Mexico project.

# %%
# !pip install openpyxl
import pandas as pd

# Load the data
data_path = '../data/raw/housing_data.xlsx'  # relative path from notebooks folder
df = pd.read_excel(data_path)

# Quick check
df.head()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
#               City  Single family  Condo or co-op  All homes  \
# 0      Atlanta, GA         403000          298000     317000
# 1  Minneapolis, MN         331000          291000     323000
# 2   Cincinatti, OH         208000          211000     191000
# 3    San Diego, CA         829000          536000     725000
# 4         Reno, NV         450000          247000     441000
#
#    Household income  Unemployment  Population
# 0             55279           8.5      498044
# 1             58993           7.5      425403
# 2             38545          10.1      302605
# 3             75456           8.8     1426000
# 4             54916           6.9      250998
